# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns

# %%
df = pd.read_excel('data.xlsx')
df.columns = ['room', 'sq_m', 'floor', 'year', 'location', 'price']
df.head()
# Out:
#    room   sq_m floor  year             location      price
# 0     3   71.0   NaN  1990  Turksibsky district   35500000
# 1     7  420.0     2  2021  Turksibsky district  168000000
# 2     4  124.0     2  2005      Alatau district   50000000
# 3    10  260.0     3  2016                other   75000000
# 4     7  390.0     2  2021   Auezovsky district  550000000

# %%
df.shape
# Out:
# (10041, 6)

# %%
df.isnull().sum()
# Out:
# room           0
# sq_m           0
# floor        756
# year        1425
# location       0
# price          0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# room        0
# sq_m        0
# floor       0
# year        0
# location    0
# price       0
# dtype: int64

# %%
df.shape
# Out:
# (8299, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8299 entries, 1 to 10040
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   room      8299 non-null   int64
#  1   sq_m      8299 non-null   float64
#  2   floor     8299 non-null   object
#  3   year      8299 non-null   object
#  4   location  8299 non-null   object
#  5   price     8299 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 453.9+ KB

# %%
df.groupby('floor')['floor'].agg('count')
# Out:
# floor
# 1                                                                                                                                                                                                                                                     3397
# 10                                                                                                                                                                                                                                                       1
# 110                                                                                                                                                                                                                                                      1
# ...

# %%
values = ['1', '2', '3', '4']

df = df[df.floor.isin (values) == True]

# %%
df.shape
# Out:
# (8091, 6)

# %%
df.groupby('floor')['floor'].agg('count')
# Out:
# floor
# 1    3397
# 2    3007
# 3    1467
# 4     220
# Name: floor, dtype: int64

# %%
df['floor'] = df['floor'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8091 entries, 1 to 10040
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   room      8091 non-null   int64
#  1   sq_m      8091 non-null   float64
#  2   floor     8091 non-null   int32
#  3   year      8091 non-null   object
#  4   location  8091 non-null   object
#  5   price     8091 non-null   object
# dtypes: float64(1), int32(1), int64(1), object(3)
# memory usage: 410.9+ KB

# %%
df.groupby('year')['year'].agg('count')
# Out:
# year
# 1917                   1
# 1918                   1
# 1919                   1
# 1922                   1
# 1923                   1
#                       ..
# 2024                   4
# 2026                   1
# жил. площадь 435 м²    1
# жил. площадь 49 м²     1
# санузел во дворе       1
# Name: year, Length: 93, dtype: int64

# %%
values = ['2026', 'жил. площадь 435 м²', 'жил. площадь 49 м²', 'санузел во дворе']

df = df[df.year.isin (values) == False]

# %%
df.groupby('year')['year'].agg('count')
# Out:
# year
# 1917      1
# 1918      1
# 1919      1
# 1922      1
# 1923      1
#        ...
# 2020    261
# 2021    299
# 2022    439
# 2023    291
# 2024      4
# Name: year, Length: 89, dtype: int64

# %%
df['year'] = df['year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8087 entries, 1 to 10040
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   room      8087 non-null   int64
#  1   sq_m      8087 non-null   float64
#  2   floor     8087 non-null   int32
#  3   year      8087 non-null   int32
#  4   location  8087 non-null   object
#  5   price     8087 non-null   object
# dtypes: float64(1), int32(2), int64(1), object(2)
# memory usage: 379.1+ KB

# %%
df['room'].unique()
# Out:
# array([ 7,  4, 10,  3,  2,  5,  8,  6,  1,  9, 12, 23, 13, 30, 20, 11, 15,
#        38, 16, 35, 14, 19, 50, 18, 17, 41, 27, 24, 34, 25, 37],
#       dtype=int64)

# %%
df.room.value_counts()
# Out:
# 5     1876
# 4     1589
# 6     1339
# 3      962
# 7      897
# 8      497
# 2      298
# 10     203
# 9      175
# 12      67
# 11      55
# 1       31
# 15      20
# 14      15
# 13      14
# 20      14
# 17       7
# 18       5
# 19       4
# 16       4
# 24       3
# 23       2
# 30       2
# 50       1
# 35       1
# 38       1
# 41       1
# 27       1
# 34       1
# 25       1
# 37       1
# Name: room, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.countplot(df, x='room', ax=ax)
# Out:
# <Axes: xlabel='room', ylabel='count'>

# %%
values = [2, 3, 4, 5, 6, 7, 8]

df = df[df.room.isin (values) == True]

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.countplot(df, x='room', ax=ax)
# Out:
# <Axes: xlabel='room', ylabel='count'>

# %%
df.shape
# Out:
# (7458, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7458 entries, 1 to 10040
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   room      7458 non-null   int64
#  1   sq_m      7458 non-null   float64
#  2   floor     7458 non-null   int32
#  3   year      7458 non-null   int32
#  4   location  7458 non-null   object
#  5   price     7458 non-null   object
# dtypes: float64(1), int32(2), int64(1), object(2)
# memory usage: 349.6+ KB

# %%
df.price.value_counts()
# Out:
# 45000000     217
# 55000000     201
# 65000000     194
# 35000000     180
# 40000000     175
#             ...
# 140666666      1
# 383000000      1
# 79500000       1
# 109500000      1
# 21300000       1
# Name: price, Length: 731, dtype: int64

# %%
df['price'] = df['price'].astype(np.int64)

# %%
df['price'] = df['price'] / 1000000

# %%
df.head()
# Out:
#    room   sq_m  floor  year             location  price
# 1     7  420.0      2  2021  Turksibsky district  168.0
# 2     4  124.0      2  2005      Alatau district   50.0
# 4     7  390.0      2  2021   Auezovsky district  550.0
# 5     4  155.2      2  2004   Nauryzbay district   85.0
# 6     3  120.0      1  2012   Nauryzbay district   65.0

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.distplot(df['price'], kde=False, bins=30, ax=ax)
# Out:
# C:\Users\qniu\AppData\Local\Temp\ipykernel_36188\1253351179.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], kde=False, bins=30, ax=ax)
# <Axes: xlabel='price'>

# %%
df['price'].min()
# Out:
# 4.5

# %%
df['price'].max()
# Out:
# 3360.0

# %%
df[df['price'] == 4.5]
# Out:
#       room  sq_m  floor  year location  price
# 2415     2  65.0      2  1983    other    4.5

# %%
df[df['price'] == 3360.0]
# Out:
#       room    sq_m  floor  year        location   price
# 926      8  1653.9      3  2021  Medeu district  3360.0
# 9568     8  1600.0      3  2019  Medeu district  3360.0

# %%
df.shape
# Out:
# (7458, 6)

# %%
df[df['price'] < 15]['price'].count()
# Out:
# 51

# %%
df[df['price'] > 350]
# Out:
#        room   sq_m  floor  year            location       price
# 4         7  390.0      2  2021  Auezovsky district  550.000000
# 23        8  510.0      2  2023  Bostandyk district  387.000000
# 55        8  660.0      3  2018  Bostandyk district  420.000000
# 80        7  640.0      2  2022  Auezovsky district  589.999998
# 118       7  326.0      2  2012      Medeu district  380.000000
# ...     ...    ...    ...   ...                 ...         ...
# 9634      6  693.0      4  2018      Medeu district  570.000000
# 9707      7  303.0      2  2008      Medeu district  675.000000
# 9977      7  521.0      2  2012  Bostandyk district  450.000000
# 9993      7  480.0      3  2003  Bostandyk district  450.000000
# 10017     7  382.0      2  2018  Bostandyk district  390.000000
#
# [354 rows x 6 columns]

# %%
df = df[(df['price'] > 15) & (df['price'] < 351)]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.distplot(df.price, kde=False, bins=30, ax=ax)
# Out:
# C:\Users\qniu\AppData\Local\Temp\ipykernel_36188\1046984644.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.price, kde=False, bins=30, ax=ax)
# <Axes: xlabel='price'>

# %%
df.shape
# Out:
# (7036, 6)

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.countplot(df, x='room', ax=ax)
# Out:
# <Axes: xlabel='room', ylabel='count'>

# %%
sns.jointplot(x='year',y='price',data=df,kind='scatter')

# %%
df = df[df['year'] > 1955]

# %%
sns.jointplot(x='year',y='price',data=df,kind='scatter', hue='room', xlim=[1950, 2025], ylim=[0, 360])

# %%
df[(df['year'] < 1990) & (df['price'] > 125)].tail(6)
# Out:
#       room   sq_m  floor  year             location  price
# 8324     8  300.0      3  1986   Nauryzbay district  160.0
# 8944     4   74.0      1  1964   Bostandyk district  150.0
# 9107     7  360.0      2  1980      Alatau district  149.0
# 9537     6  235.0      2  1975  Turksibsky district  130.0
# 9560     3   70.0      1  1963       Medeu district  130.0
# 9643     4  115.0      2  1962       Medeu district  160.0

# %%
sns.jointplot(y='sq_m',x='price',data=df,kind='scatter', hue='year', xlim=[0, 350], ylim=[0, 1300])

# %%
df = df[df['sq_m'] < 560]

# %%
sns.jointplot(y='sq_m',x='price',data=df,kind='scatter', hue='year', xlim=[0, 170], ylim=[0, 600])

# %%
df.location.value_counts()
# Out:
# Alatau district        1758
# Nauryzbay district     1371
# Medeu district         1014
# Turksibsky district     853
# Bostandyk district      675
# Zhetysu district        510
# Auezovsky district      298
# other                   264
# Almaly district         155
# Name: location, dtype: int64

# %%
df.shape
# Out:
# (6898, 6)

# %%
dummies = pd.get_dummies(df.location)
dummies.head(3)
# Out:
#    Alatau district  Almaly district  Auezovsky district  Bostandyk district  \
# 1                0                0                   0                   0
# 2                1                0                   0                   0
# 5                0                0                   0                   0
#
#    Medeu district  Nauryzbay district  Turksibsky district  Zhetysu district  \
# 1               0                   0                    1                 0
# 2               0                   0                    0                 0
# 5               0                   1                    0                 0
#
#    other
# 1      0
# 2      0
# 5      0

# %%
df1 = pd.concat([df,dummies.drop('other',axis='columns')],axis='columns')
df1.head()
# Out:
#    room   sq_m  floor  year             location  price  Alatau district  \
# 1     7  420.0      2  2021  Turksibsky district  168.0                0
# 2     4  124.0      2  2005      Alatau district   50.0                1
# 5     4  155.2      2  2004   Nauryzbay district   85.0                0
# 6     3  120.0      1  2012   Nauryzbay district   65.0                0
# 7     4  158.0      2  2006       Medeu district   61.0                0
#
#    Almaly district  Auezovsky district  Bostandyk district  Medeu district  \
# 1                0                   0                   0               0
# 2                0                   0                   0               0
# 5                0                   0                   0               0
# 6                0                   0                   0               0
# 7                0                   0                   0               1
#
#    Nauryzbay district  Turksibsky district  Zhetysu district
# ...

# %%
df1 = df1.drop('location',axis=1)
df1.head(2)
# Out:
#    room   sq_m  floor  year  price  Alatau district  Almaly district  \
# 1     7  420.0      2  2021  168.0                0                0
# 2     4  124.0      2  2005   50.0                1                0
#
#    Auezovsky district  Bostandyk district  Medeu district  Nauryzbay district  \
# 1                   0                   0               0                   0
# 2                   0                   0               0                   0
#
#    Turksibsky district  Zhetysu district
# 1                    1                 0
# 2                    0                 0

# %%
X = df1.drop('price', axis=1)
X.head()
# Out:
#    room   sq_m  floor  year  Alatau district  Almaly district  \
# 1     7  420.0      2  2021                0                0
# 2     4  124.0      2  2005                1                0
# 5     4  155.2      2  2004                0                0
# 6     3  120.0      1  2012                0                0
# 7     4  158.0      2  2006                0                0
#
#    Auezovsky district  Bostandyk district  Medeu district  Nauryzbay district  \
# 1                   0                   0               0                   0
# 2                   0                   0               0                   0
# 5                   0                   0               0                   1
# 6                   0                   0               0                   1
# 7                   0                   0               1                   0
#
#    Turksibsky district  Zhetysu district
# 1                    1                 0
# ...

# %%
y = df1.price
y.head()
# Out:
# 1    168.0
# 2     50.0
# 5     85.0
# 6     65.0
# 7     61.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.6692161678657378

# %% [markdown]
# #### Using K Fold cross validation to measure accuracy of our LinearRegression model

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.60295237, 0.64205171, 0.63297224, 0.64498331, 0.63118222])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'fit_intercept': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
# C:\Users\qniu\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\qniu\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\qniu\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\qniu\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
# ...

# %%
df.columns
# Out:
# Index(['room', 'sq_m', 'floor', 'year', 'location', 'price'], dtype='object')

# %%
df.location.unique()
# Out:
# array(['Turksibsky district', 'Alatau district', 'Nauryzbay district',
#        'Medeu district', 'Auezovsky district', 'other',
#        'Zhetysu district', 'Bostandyk district', 'Almaly district'],
#       dtype=object)

# %%
np.where(X.columns=='Alatau district')[0][0]
# Out:
# 4

# %%
def predict_price(room, sq_m, floor, year, location):    
    loc_index = np.where(X.columns==location)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = room
    x[1] = sq_m
    x[2] = floor
    x[3] = year
    if loc_index >= 0:
        x[loc_index] = 1
    return model.predict([x])[0]

# %%
predict_price(5, 406, 3, 2015, 'Alatau district')
# Out:
# C:\Users\qniu\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 157.97207959762764

# %%
predict_price(7, 550, 3, 2018, 'Nauryzbay district')
# Out:
# C:\Users\qniu\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 234.5265416498314

# %%
predict_price(5, 250, 3, 2012, 'Medeu district')
# Out:
# C:\Users\qniu\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 133.8174624230359

# %%
predict_price(5, 200, 1, 2001, 'Turksibsky district')
# Out:
# C:\Users\qniu\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 84.97249968264086

# %%
import pickle
with open('almaty_home_prices_model.pickle','wb') as f:
    pickle.dump(model,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6898 entries, 1 to 10040
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   room      6898 non-null   int64
#  1   sq_m      6898 non-null   float64
#  2   floor     6898 non-null   int32
#  3   year      6898 non-null   int32
#  4   location  6898 non-null   object
#  5   price     6898 non-null   float64
# dtypes: float64(2), int32(2), int64(1), object(1)
# memory usage: 323.3+ KB

# %%
df.floor.unique()
# Out:
# array([2, 1, 3, 4])
